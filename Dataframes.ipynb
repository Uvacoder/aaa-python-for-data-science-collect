# %%
import pandas as pd

# %%
# Method 1: Specify full path to file

# %%
# Windows:
#stats = pd.read_csv('C:\\Users\\username\\Desktop\\Python Programming Course')

# %%
# Mac
stats = pd.read_csv('/Users/diogobcondeco/Personal/python-for-data-science/CSVs/DemographicData.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
# Method 2: Change Working Directory

# %%
import os

# %%
print(os.getcwd())
# Out:
# /Users/diogobcondeco/Personal/python-for-data-science

# %%
# Windows
#os.chdir('C:\\Users\\username\\Desktop')

# %%
# Mac
#os.chdir('/Users/diogobcondeco/Personal/python-for-data-science/CSVs')

# %%
# if os.chdir above is used
#stats2 = pd.read_csv('DemographicData.csv')

stats2 = pd.read_csv(os.getcwd() + '/CSVs/DemographicData.csv')

# %%
stats2
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %% [markdown]
# ---

# %%
# Exploring your data

# %%
# 1. Full Dataframe
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
# 2. Number of rows
len(stats) # 195 rows imported
# Out:
# 195

# %%
# 3. See columns
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
# 4. Number of columns
len(stats.columns) # 5 columns imported
# Out:
# 5

# %%
# 5. Top rows
stats.head() # remember the brackets
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.head(6)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
# 6. Bottom rows
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats.tail(6)
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 189             Samoa          WSM      26.172            15.3
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# 7. Information on the columns
stats.info() # like the str() in R
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
# 8. Get stats on the columns
stats.describe() # like summary() in R
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %% [markdown]
# ---

# %%
# Renaming columns of a Dataframe

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns = ["a", "b", "c", "d", "e"]

# %%
stats
# Out:
#                         a    b       c     d                    e
# 0                   Aruba  ABW  10.244  78.9          High income
# 1             Afghanistan  AFG  35.253   5.9           Low income
# 2                  Angola  AGO  45.985  19.1  Upper middle income
# 3                 Albania  ALB  12.877  57.2  Upper middle income
# 4    United Arab Emirates  ARE  11.044  88.0          High income
# ..                    ...  ...     ...   ...                  ...
# 190           Yemen, Rep.  YEM  32.947  20.0  Lower middle income
# 191          South Africa  ZAF  20.850  46.5  Upper middle income
# 192      Congo, Dem. Rep.  COD  42.394   2.2           Low income
# 193                Zambia  ZMB  40.471  15.4  Lower middle income
# 194              Zimbabwe  ZWE  35.715  18.5           Low income
#
# [195 rows x 5 columns]

# %%
stats.columns = ['CountryName', 'CountryCode', \
                 'BirthRate', 'InternetUsers', \
                 'IncomeGroup']

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %% [markdown]
# ---

# %%
# Subsetting dataframes in Pandas

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Three parts. Buckle Up!
# - Rows
# - Columns
# - Combining the two

# %%
# Part 1. Rows

# %%
stats[21:23]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 21      Belize         BLZ     23.092           33.6  Upper middle income
# 22     Bermuda         BMU     10.400           95.3          High income

# %%
# Quick exercise - reverse the dataframe

# %%
stats[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
# Quick exercise - get only every 20th row

# %%
stats[::20]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %%
# Part 2. Columns

# %%
stats["CountryName"]
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
stats["CountryName"].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
stats[["CountryName", "CountryCode"]].head()
# Out:
#             CountryName CountryCode
# 0                 Aruba         ABW
# 1           Afghanistan         AFG
# 2                Angola         AGO
# 3               Albania         ALB
# 4  United Arab Emirates         ARE

# %%
stats[["CountryCode", "CountryName"]].head()
# Out:
#   CountryCode           CountryName
# 0         ABW                 Aruba
# 1         AFG           Afghanistan
# 2         AGO                Angola
# 3         ALB               Albania
# 4         ARE  United Arab Emirates

# %%
# Quick Access - requires the name to be one word

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
print(stats["BirthRate"].head(2))
print(stats.BirthRate.head(2))
# Out:
# 0    10.244
# 1    35.253
# Name: BirthRate, dtype: float64
# 0    10.244
# 1    35.253
# Name: BirthRate, dtype: float64

# %%
# Part 3. Combining the two

# %%
stats[4:8]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
# 7   Antigua and Barbuda         ATG     16.447           63.4
#
#            IncomeGroup
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income

# %%
stats[4:8][["CountryName", "BirthRate"]]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
stats[["CountryName", "BirthRate"]][4:8]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
df1 = stats[4:8]
df1[["CountryName", "BirthRate"]]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
df2 = stats[["CountryName", "BirthRate"]]
df2[4:8]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %% [markdown]
# ---

# %%
# Basic Operations with Dataframes

# %%
# Already spoke about subsetting. Refresh:
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[6:9][["CountryName", "IncomeGroup"]]
# Out:
#            CountryName          IncomeGroup
# 6              Armenia  Lower middle income
# 7  Antigua and Barbuda          High income
# 8            Australia          High income

# %%
# Mathematical Operations

# %%
result = stats.BirthRate * stats.InternetUsers

# %%
result.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
# Add column:

# %%
stats["MyCalc"] = stats.BirthRate * stats.InternetUsers

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
# Renaming a specific column
stats = stats.rename(columns={"MyCalc": "BirthRateXInternetUsers"})

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  BirthRateXInternetUsers
# 0          High income                 808.2516
# 1           Low income                 207.9927
# 2  Upper middle income                 878.3135
# 3  Upper middle income                 736.5644
# 4          High income                 971.8720

# %%
# Removing a column

# %%
stats = stats.drop("BirthRateXInternetUsers", axis=1) # axis is 0 by default, if axis=0, it deletes rows
#stats = stats.drop("BirthRateXInternetUsers", axis=1)

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Another way to remove a column

# %%
stats["test"] = "1"

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup test
# 0          High income    1
# 1           Low income    1
# 2  Upper middle income    1
# 3  Upper middle income    1
# 4          High income    1

# %%
del stats["test"]

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# ---

# %%
# Filtering Dataframes

# %%
# Filtering is about Rows

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.InternetUsers < 2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
Filter = stats.InternetUsers < 2

# %%
Filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
stats[Filter]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
stats[stats.InternetUsers < 2]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
stats[stats.BirthRate > 40].head()
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 2          Angola         AGO     45.985           19.1  Upper middle income
# 11        Burundi         BDI     44.151            1.3           Low income
# 14   Burkina Faso         BFA     40.551            9.1           Low income
# 65    Gambia, The         GMB     42.525           14.0           Low income
# 115          Mali         MLI     44.138            3.5           Low income

# %%
stats[stats.BirthRate < 10].head()
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 9                  Austria         AUT      9.400        80.6188
# 16                Bulgaria         BGR      9.200        53.0615
# 19  Bosnia and Herzegovina         BIH      9.062        57.7900
# 45                 Germany         DEU      8.500        84.1700
# 53                   Spain         ESP      9.100        71.6350
#
#             IncomeGroup
# 9           High income
# 16  Upper middle income
# 19  Upper middle income
# 45          High income
# 53          High income

# %%
stats[stats.IncomeGroup == "High income"].head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                 Aruba         ABW     10.244           78.9  High income
# 4  United Arab Emirates         ARE     11.044           88.0  High income
# 5             Argentina         ARG     17.716           59.9  High income
# 7   Antigua and Barbuda         ATG     16.447           63.4  High income
# 8             Australia         AUS     13.200           83.0  High income

# %%
stats[(stats.BirthRate < 10) & (stats.IncomeGroup == "High income")]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 9                 Austria         AUT        9.4        80.6188  High income
# 45                Germany         DEU        8.5        84.1700  High income
# 53                  Spain         ESP        9.1        71.6350  High income
# 68                 Greece         GRC        8.5        59.8663  High income
# 74   Hong Kong SAR, China         HKG        7.9        74.2000  High income
# 76                Croatia         HRV        9.4        66.7476  High income
# 78                Hungary         HUN        9.2        72.6439  High income
# 86                  Italy         ITA        8.5        58.4593  High income
# 89                  Japan         JPN        8.2        89.7100  High income
# 95            Korea, Rep.         KOR        8.6        84.7700  High income
# 102         Liechtenstein         LIE        9.2        93.8000  High income
# ...

# %%
stats[stats.InternetUsers > 90]
# Out:
#        CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 17         Bahrain         BHR      15.04       90.00004  High income
# 22         Bermuda         BMU      10.40       95.30000  High income
# 47         Denmark         DNK      10.00       94.62970  High income
# 56         Finland         FIN      10.70       91.51440  High income
# 84         Iceland         ISL      13.40       96.54680  High income
# 102  Liechtenstein         LIE       9.20       93.80000  High income
# 106     Luxembourg         LUX      11.30       93.77650  High income
# 130    Netherlands         NLD      10.20       93.95640  High income
# 131         Norway         NOR      11.60       95.05340  High income
# 163         Sweden         SWE      11.80       94.78360  High income

# %%
# How to get the unique categories
stats.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
# Quick Exercise - Find out everything about Malta

# %%
stats[stats.CountryName == "Malta"]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 116       Malta         MLT        9.5        68.9138  High income

# %%
stats.max()
# Out:
# CountryName                 Zimbabwe
# CountryCode                      ZWE
# BirthRate                     49.661
# InternetUsers                96.5468
# IncomeGroup      Upper middle income
# dtype: object

# %%
# Getting info about the highest number of InternetUsers
stats[stats.InternetUsers == max(stats.InternetUsers)]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 84     Iceland         ISL       13.4        96.5468  High income

# %%
# Sort by the Top 5 countries with the most InternetUsers, order: descending
stats.sort_values(by="InternetUsers", ascending=False).head()
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 84      Iceland         ISL       13.4        96.5468  High income
# 22      Bermuda         BMU       10.4        95.3000  High income
# 131      Norway         NOR       11.6        95.0534  High income
# 163      Sweden         SWE       11.8        94.7836  High income
# 47      Denmark         DNK       10.0        94.6297  High income

# %% [markdown]
# ---

# %%
# Accessing individual elements

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# .at #for labels. Important: even integers are treated as labels
# .iat #for integer location

# %%
stats.iat[3,4]
# Out:
# 'Upper middle income'

# %%
stats.iat[0,1]
# Out:
# 'ABW'

# %%
stats.at[2, "BirthRate"]
# Out:
# 45.985

# %%
sub10 = stats[::10]

# %%
sub10
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
sub10.iat[10,0]
# Out:
# 'Libya'

# %%
sub10.at[10, "CountryName"]
# Out:
# 'Azerbaijan'

# %% [markdown]
# ---

# %%
# Introduction to Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams["figure.figsize"]= 8,4
import warnings
warnings.filterwarnings("ignore")

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Distribution:
vis1 = sns.distplot(stats["InternetUsers"], bins=5)

# %%
# Boxplots:
vis2 = sns.boxplot(data=stats, x="IncomeGroup", y="BirthRate")

# %%
# Seaborn Gallery

# %% [markdown]
# ---

# %%
vis3 = sns.lmplot(data=stats, x="InternetUsers", y="BirthRate", fit_reg=False)

# %%
vis3 = sns.lmplot(data=stats, x="InternetUsers", y="BirthRate", \
                  fit_reg=False, hue="IncomeGroup", \
                  size=7, aspect=1.5)

# %% [markdown]
# ---

# %%
# Keyword Arguments in Python (advanced tutorial)

# %%
# marker size:

# %%
vis3 = sns.lmplot(data=stats, x="InternetUsers", y="BirthRate", \
                  fit_reg=False, hue="IncomeGroup", \
                  size=7, aspect=1.5, \
                  scatter_kws={"s": 150})
