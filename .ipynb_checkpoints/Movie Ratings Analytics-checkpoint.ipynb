# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/diogobcondeco/Personal/python-for-data-science'

# %%
movies = pd.read_csv(os.getcwd() + "/CSVs/MovieRatings.csv")

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ["Film", "Genre", \
                  "CriticRating", "AudienceRating", \
                  "BudgetMillions", "Year"]

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.Film = movies.Film.astype("category")

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    object
# dtypes: category(1), int64(3), object(2)
# memory usage: 43.6+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
movies.Genre = movies.Genre.astype("category")
movies.Year = movies.Year.astype("category")

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %% [markdown]
# ---

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# Jointplots

# %%
j = sns.jointplot(data=movies, x="CriticRating", y="AudienceRating")

# %%
j = sns.jointplot(data=movies, x="CriticRating", y="AudienceRating", kind="hex")

# %%
j = sns.jointplot(data=movies, x="CriticRating", y="BudgetMillions")

# %%
j = sns.jointplot(data=movies, x="AudienceRating", y="BudgetMillions")

# %%
movies[(movies.AudienceRating > 80) & (movies.BudgetMillions < 20)]
# Out:
#                                Film      Genre  CriticRating  AudienceRating  \
# 0             (500) Days of Summer      Comedy            87              81
# 3                         127 Hours  Adventure            93              84
# 9                             50/50     Comedy            93              93
# 47               Black Swan              Drama            88              86
# 158          Hachiko: A Dog's Story      Drama            58              85
# 195                   Into the Wild      Drama            82              90
# 207                            Juno     Comedy            94              89
# 244               Midnight in Paris    Romance            93              84
# 260            My Week with Marilyn      Drama            83              84
# 365          Step Up 2: The Streets      Drama            26              81
# 379                    Take Shelter      Drama            92              85
# ...

# %% [markdown]
# ---

# %%
# Histograms

# %%
# Already know this method:
m1 = sns.distplot(movies.AudienceRating, bins=10)

# %%
m2 = sns.distplot(movies.CriticRating, bins=10)

# %%
n1 = plt.hist(movies.AudienceRating, bins=10)

# %%
n2 = plt.hist(movies.CriticRating, bins=10)

# %% [markdown]
# ---

# %%
# Stacked Histograms

# %%
h1 = plt.hist(movies.BudgetMillions)

# %%
plt.hist(movies[movies.Genre == "Action"].BudgetMillions, bins=15)
plt.hist(movies[movies.Genre == "Drama"].BudgetMillions, bins=15)
plt.hist(movies[movies.Genre == "Thriller"].BudgetMillions, bins=15)
plt.show()

# %%
genresMillions = [movies[movies.Genre == "Action"].BudgetMillions, \
                  movies[movies.Genre == "Drama"].BudgetMillions, \
                  movies[movies.Genre == "Thriller"].BudgetMillions]

plt.hist(genresMillions, bins=15, stacked=True)
plt.show()

# %%
list1 = list()
mylabels = list()

for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)

# %%
plt.hist(list1, bins=30, stacked=True, label=mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %%
# KDR Plot (Kernel Density Entity)

# %%
vis1 = sns.lmplot(data=movies, x="CriticRating", y="AudienceRating", \
                  fit_reg=False, hue="Genre", \
                  size=7, aspect=1.5, \
                  scatter_kws={"s": 100})

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                 shade=True, shade_lowest=False, \
                 cmap="Reds")

# TIP:
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                 cmap="Reds")

# %% [markdown]
# ---

# %%
# Working with Subplots()

# %%
sns.set_style("dark")
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)

# %%
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)

# %%
f, ax = plt.subplots(1, 2, figsize=(12,6), sharex=True, sharey=True)
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=ax[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=ax[1])
k1.set(xlim=(-40, 200))
k1.set(ylim=(-20, 120))
# Out:
# [(-20.0, 120.0)]

# %%
f, ax = plt.subplots(2, 2, figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=ax[0, 0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=ax[0, 1])

# %% [markdown]
# ---

# %%
# Violin Plots

# %%
z = sns.boxplot(data=movies, x="Genre", y="CriticRating")

# %%
z = sns.violinplot(data=movies, x="Genre", y="CriticRating")

# %%
z = sns.boxplot(data=movies[movies.Genre == "Drama"], x="Year", y="CriticRating")

# %%
z = sns.violinplot(data=movies[movies.Genre == "Drama"], x="Year", y="CriticRating")

# %% [markdown]
# ---

# %%
# Creating a Facet Grid

# %%
#g = sns.FacetGrid(movies, row="Genre", hue="Genre")
g = sns.FacetGrid(movies, row="Genre", col="Year", hue="Genre")

# %%
g = sns.FacetGrid(movies, row="Genre", col="Year", hue="Genre")
g = g.map(plt.scatter, "CriticRating", "AudienceRating")

# %%
g = sns.FacetGrid(movies, row="Genre", col="Year", hue="Genre")
g = g.map(plt.hist, "BudgetMillions")

# %%
g = sns.FacetGrid(movies, row="Genre", col="Year", hue="Genre")
kws = dict(s=50, linewidth=0.5, edgecolor="black")
g = g.map(plt.scatter, "CriticRating", "AudienceRating", **kws)

# %% [markdown]
# ---

# %%
# Controlling axes and adding diagonals
g = sns.FacetGrid(movies, row="Genre", col="Year", hue="Genre")
kws = dict(s=50, linewidth=0.5, edgecolor="black")
g = g.map(plt.scatter, "CriticRating", "AudienceRating", **kws)
g.set(xlim=(0, 100), ylim=(0, 100))

for ax in g.axes.flat:
    ax.plot((0, 100), (0, 100), c="grey", ls="--")

g.add_legend()

# %% [markdown]
# ---

# %%
# Building Dashboards

# %%
sns.set_style("darkgrid")
f, ax = plt.subplots(2, 2, figsize=(15,15))

k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, \
                 ax=ax[0, 0])       

k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, \
                 ax=ax[0, 1])

z = sns.violinplot(data=movies[movies.Genre == "Drama"], x="Year", y="CriticRating", ax=ax[1, 0])
#ax[1,0].hist(movies.BudgetMillions, bins=15)

k3 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                 shade=True, shade_lowest=False, \
                 cmap="Reds", ax=ax[1,1])
k3b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                 cmap="Reds", ax=ax[1,1])

k1.set(xlim=(-40, 230))
k2.set(xlim=(-40, 230))
# Out:
# [(-40.0, 230.0)]

# %% [markdown]
# ---

# %%
# Styling Dashboards

# %%
sns.set_style("white", {"axes.facecolor": "black"})
f, ax = plt.subplots(2, 2, figsize=(15,15))

# Plot 0,0
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, \
                 shade=True, shade_lowest=True, cmap="inferno", \
                 ax=ax[0, 0])
k1b = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, \
                 cmap="cool", \
                 ax=ax[0, 0])

# Plot 0,1
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, \
                 shade=True, shade_lowest=True, cmap="inferno", \
                 ax=ax[0, 1])
k2b = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, \
                 cmap="cool", \
                 ax=ax[0, 1])

# Plot 1,0
z = sns.violinplot(data=movies, x="Year", y="BudgetMillions", \
                   palette="YlOrRd", \
                   ax=ax[1, 0])
#ax[1,0].hist(movies.BudgetMillions, bins=15)

# Plot 1,1
k3 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                 shade=True, shade_lowest=False, \
                 cmap="Blues_r", ax=ax[1,1])
k3b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                 cmap="gist_gray_r", ax=ax[1,1])

k1.set(xlim=(-40, 230))
k2.set(xlim=(-40, 230))
plt.show()

# %%
# Thematic Edits

# %%
list1 = list()
mylabels = list()

for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)

sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27) # size of A4 paper
plt.hist(list1, bins=30, \
         stacked=True, label=mylabels, \
         color=["Red", "Salmon", "Blue", "Green", "Purple", "Orange", "Cyan"])
plt.title("Movie Budget Distribution", fontsize=35, color="darkblue")
plt.ylabel("Number of Movies", fontsize=25, color="red")
plt.xlabel("Budget", fontsize=25, color="green")
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.legend(frameon=True, fancybox=True, \
           shadow=True, framealpha=1, \
           prop={"size":20})
plt.show()
